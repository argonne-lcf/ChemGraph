# %%
#Visualize the agentic system

from comp_chem_agent.agent.llm_graph import *
system_prompt = """You are an expert in computational chemistry and molecular simulation. Your task is to generate and execute Python code to address the user's query accurately and efficiently.

Follow these steps:
1. **Generate Python Code**: Write well-structured and optimized Python code tailored to the user's request.
2. **Execute the Code**: Run the generated code using your execution tool to provide a complete and verified response.
3. **Ensure Accuracy**: Validate the results before presenting them to the user, ensuring correctness and relevance to their query.

Your response should be precise, relevant, and formatted for clarity."""

workflow_type = "python_relp" 
cca = llm_graph(model_name='gpt-4o', workflow_type = workflow_type, system_prompt=system_prompt)
cca.visualize()
# Out:
# 2025-03-19 13:54:23,648 - comp_chem_agent.tools.openai_loader - INFO - Loading OpenAI model: gpt-4o
# 2025-03-19 13:54:23,671 - comp_chem_agent.tools.openai_loader - INFO - Requested model: gpt-4o
# 2025-03-19 13:54:23,672 - comp_chem_agent.tools.openai_loader - INFO - OpenAI model loaded successfully
# 2025-03-19 13:54:23,672 - comp_chem_agent.graphs.python_relp_agent - INFO - Constructing geometry optimization graph
# 2025-03-19 13:54:23,673 - comp_chem_agent.graphs.python_relp_agent - INFO - Graph construction completed

# %%
query = "Run geometry optimization for CO2 using ASE and emt"
cca.run(query, config={"configurable": {"thread_id": "2"}})
# Out:
# ================================ Human Message =================================
#
# Run geometry optimization for CO2 using ASE and emt
# ================================== Ai Message ==================================
# Tool Calls:
#   python_repl (call_BwvKt7fPLU7bsWDjZLYgnG2w)
#  Call ID: call_BwvKt7fPLU7bsWDjZLYgnG2w
#   Args:
#     __arg1: from ase import Atoms
# from ase.calculators.emt import EMT
# from ase.optimize import BFGS
#
# # Define the CO2 molecule
# co2 = Atoms('CO2', positions=[(0, 0, 0), (1.16, 0, 0), (-1.16, 0, 0)])
#
# # Set the EMT calculator
# co2.set_calculator(EMT())
#
# # Perform geometry optimization
# optimizer = BFGS(co2)
# optimizer.run(fmax=0.05)
#
# # Get the optimized positions
# optimized_positions = co2.get_positions()
# print(optimized_positions)
# ================================= Tool Message =================================
# Name: python_repl
#
# ...

# %%
query = "Reduce the convergence criteria to 0.001 and rerun the simulation"
cca.run(query, config={"configurable": {"thread_id": "2"}})
# Out:
# ================================ Human Message =================================
#
# Reduce the convergence criteria to 0.001 and rerun the simulation
# ================================== Ai Message ==================================
# Tool Calls:
#   python_repl (call_1MtLjHIdaWb76Z9kb6rDPlIF)
#  Call ID: call_1MtLjHIdaWb76Z9kb6rDPlIF
#   Args:
#     __arg1: from ase import Atoms
# from ase.calculators.emt import EMT
# from ase.optimize import BFGS
#
# # Define the CO2 molecule
# co2 = Atoms('CO2', positions=[(0, 0, 0), (1.16, 0, 0), (-1.16, 0, 0)])
#
# # Set the EMT calculator
# co2.set_calculator(EMT())
#
# # Perform geometry optimization with stricter convergence criteria
# optimizer = BFGS(co2)
# optimizer.run(fmax=0.001)
#
# # Get the optimized positions
# optimized_positions = co2.get_positions()
# print(optimized_positions)
# ================================= Tool Message =================================
# Name: python_repl
#
# ...

# %%
query = "Calculate the vibrational frequency of CO2."
cca.run(query, config={"configurable": {"thread_id": "2"}})
# Out:
# ================================ Human Message =================================
#
# Calculate the vibrational frequency of CO2.
# ================================== Ai Message ==================================
# Tool Calls:
#   python_repl (call_tCaXo66ONUhZ2Uajh0aO3DC2)
#  Call ID: call_tCaXo66ONUhZ2Uajh0aO3DC2
#   Args:
#     __arg1: from ase import Atoms
# from ase.calculators.emt import EMT
# from ase.vibrations import Vibrations
#
# # Define the CO2 molecule
# co2 = Atoms('CO2', positions=[(0, 0, 0), (1.1299, 0, 0), (-1.1299, 0, 0)])
#
# # Set the EMT calculator
# co2.set_calculator(EMT())
#
# # Calculate vibrational frequencies
# vib = Vibrations(co2)
# vib.run()
# frequencies = vib.get_frequencies()
# print(frequencies)
#
# # Clean up
# vib.clean()
# ================================= Tool Message =================================
# Name: python_repl
#
# "IndexError('index 2 is out of bounds for axis 0 with size 2')"
# <string>:9: FutureWarning: Please use atoms.calc = calc
# ...

# %%
query = "Do vib.clean() before running the vibrational frequency."
cca.run(query, config={"configurable": {"thread_id": "2"}})
# Out:
# ================================ Human Message =================================
#
# Do vib.clean() before running the vibrational frequency.
# ================================== Ai Message ==================================
# Tool Calls:
#   python_repl (call_UkYCLcJ65TqFWkVOPF6s5rkB)
#  Call ID: call_UkYCLcJ65TqFWkVOPF6s5rkB
#   Args:
#     __arg1: from ase import Atoms
# from ase.calculators.emt import EMT
# from ase.vibrations import Vibrations
#
# # Define the CO2 molecule
# co2 = Atoms('CO2', positions=[(0, 0, 0), (1.1299, 0, 0), (-1.1299, 0, 0)])
#
# # Set the EMT calculator
# co2.set_calculator(EMT())
#
# # Calculate vibrational frequencies
# vib = Vibrations(co2)
# vib.clean()  # Clean up any previous calculations
# try:
#     vib.run()
#     frequencies = vib.get_frequencies()
#     print(frequencies)
# finally:
#     # Clean up
#     vib.clean()
# ================================= Tool Message =================================
# Name: python_repl
#
# ...

# %%
query = "How are these values compared to experimental data?"
cca.run(query, config={"configurable": {"thread_id": "2"}})
# Out:
# ================================ Human Message =================================
#
# How are these values compared to experimental data?
# ================================== Ai Message ==================================
#
# The vibrational frequencies obtained from the EMT model for CO2 are not directly comparable to experimental data due to the limitations of the EMT model. However, I can provide a general comparison with typical experimental values for CO2:
#
# ### Experimental Vibrational Frequencies for CO2:
# 1. **Symmetric Stretch**: ~1388 cm\(^{-1}\)
# 2. **Bending Mode**: ~667 cm\(^{-1}\)
# 3. **Asymmetric Stretch**: ~2349 cm\(^{-1}\)
#
# ### Comparison:
# - The EMT model provided frequencies around 642.9 cm\(^{-1}\) and 1018.6 cm\(^{-1}\), which are significantly different from the experimental values.
# - The bending mode frequency (667 cm\(^{-1}\)) is somewhat close to the 642.9 cm\(^{-1}\) value, but the other modes are not well-represented.
# ...
