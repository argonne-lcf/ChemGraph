# %% [markdown]
# # Example usage of Single-agent ChemGraph

# %% [markdown]
# ## Initiate the ChemGraph agent

# %%
from chemgraph.agent.llm_agent import ChemGraph

workflow_type = "single_agent"

# Adjust model_name with your preferred model.
cg = ChemGraph(model_name='gpt-4o-mini', workflow_type = workflow_type, structured_output=True, return_option="state")
# Out:
# /Users/tpham2/work/projects/ChemGraph/env/chemgraph_env/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# WARNING:root:fairchem is not installed. .
# 2026-01-22 11:05:26,473 - chemgraph.models.openai - INFO - OpenAI API key not found in environment variables.
# INFO:chemgraph.models.openai:OpenAI API key not found in environment variables.
# Please enter your OpenAI API key:  ········
# 2026-01-22 11:05:31,123 - chemgraph.models.openai - INFO - Loading OpenAI model: gpt-4o-mini
# INFO:chemgraph.models.openai:Loading OpenAI model: gpt-4o-mini
# 2026-01-22 11:05:31,319 - chemgraph.models.openai - INFO - Requested model: gpt-4o-mini
# INFO:chemgraph.models.openai:Requested model: gpt-4o-mini
# 2026-01-22 11:05:31,320 - chemgraph.models.openai - INFO - OpenAI model loaded successfully
# INFO:chemgraph.models.openai:OpenAI model loaded successfully
# 2026-01-22 11:05:31,320 - chemgraph.graphs.single_agent - INFO - Constructing single agent graph
# INFO:chemgraph.graphs.single_agent:Constructing single agent graph
# 2026-01-22 11:05:31,323 - chemgraph.graphs.single_agent - INFO - Graph construction completed
# INFO:chemgraph.graphs.single_agent:Graph construction completed

# %% [markdown]
# ## Visualize the single-agent ChemGraph

# %%
print(cg.visualize())
# Out:
#          +-----------+
#          | __start__ |
#          +-----------+
#                 *
#                 *
#                 *
#       +----------------+
#       | ChemGraphAgent |
#       +----------------+
#          ...        ...
#         .              .
#       ..                ..
# +-------+         +---------------+
# | tools |         | ResponseAgent |
# +-------+         +---------------+
#                           *
#                           *
#                           *
#                      +---------+
#                      | __end__ |
#                      +---------+

# %% [markdown]
# ## ChemGraph Usage Examples

# %%
# Get a SMILES string from a molecule name
query_1 = "What is the smiles string caffeine?"
result_1 = await cg.run(query_1, config={"configurable": {"thread_id": 1}})
# Out:
# ================================ Human Message =================================
#
# What is the smiles string caffeine?
# ================================== Ai Message ==================================
# Tool Calls:
#   molecule_name_to_smiles (call_bRAsSszt2QW6aelHp1zHTDmR)
#  Call ID: call_bRAsSszt2QW6aelHp1zHTDmR
#   Args:
#     name: caffeine
# ================================= Tool Message =================================
# Name: molecule_name_to_smiles
#
# CN1C=NC2=C1C(=O)N(C(=O)N2C)C
# ================================== Ai Message ==================================
#
# The SMILES string for caffeine is: **CN1C=NC2=C1C(=O)N(C(=O)N2C)C**.
# ================================ Human Message =================================
#
# {"answer":"CN1C=NC2=C1C(=O)N(C(=O)N2C)C"}

# %% [markdown]
# ## cg.run() returns a state dictionary that can be further used for analysis

# %%
print(result_1)
# Out:
# {'messages': [{'content': 'What is the smiles string caffeine?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'dc51aea6-81c8-4f20-8585-0903192315fd'}, {'content': '', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 19, 'prompt_tokens': 4163, 'total_tokens': 4182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0sPhxXLyH2rvZV9TAMvq0MMRhXll', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--4f8333a0-6e2b-459f-82e2-dba332375a5a-0', 'tool_calls': [{'name': 'molecule_name_to_smiles', 'args': {'name': 'caffeine'}, 'id': 'call_bRAsSszt2QW6aelHp1zHTDmR', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 4163, 'output_tokens': 19, 'total_tokens': 4182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': 'CN1C=NC2=C1C(=O)N(C(=O)N2C)C', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'molecule_name_to_smiles', 'id': '2e3b3360-8819-478e-83a8-b9c58b41e795', 'tool_call_id': 'call_bRAsSszt2QW6aelHp1zHTDmR', 'artifact': None, 'status': 'success'}, {'content': 'The SMILES string for caffeine is: **CN1C=NC2=C1C(=O)N(C(=O)N2C)C**.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 36, 'prompt_tokens': 4591, 'total_tokens': 4627, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0sPkUo5fmqvfbJ2M3znspmhoDIrl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--46dac326-2cb1-4ee7-81b0-e8feb8efd7ca-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 4591, 'output_tokens': 36, 'total_tokens': 4627, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '{"answer":"CN1C=NC2=C1C(=O)N(C(=O)N2C)C"}', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '6c8155d7-e255-4131-a8b8-9c3f07f76cdc'}]}

# %%
# Calculate vibrational frequency of CO2 using MACE MP
query_2 = "What are the vibrational frequencies of carbon dioxide using MACE MP?"
result_2 = await cg.run(query_2, {"thread_id": 2})
# Out:
# ================================ Human Message =================================
#
# What are the vibrational frequencies of carbon dioxide using MACE MP?
# ================================== Ai Message ==================================
# Tool Calls:
#   molecule_name_to_smiles (call_Z3FkYHIehHub0QfUBaVv8muB)
#  Call ID: call_Z3FkYHIehHub0QfUBaVv8muB
#   Args:
#     name: carbon dioxide
# ================================= Tool Message =================================
# Name: molecule_name_to_smiles
#
# C(=O)=O
# ================================== Ai Message ==================================
# Tool Calls:
#   smiles_to_coordinate_file (call_k0l7sAyWocjCVns92fi4WDQD)
#  Call ID: call_k0l7sAyWocjCVns92fi4WDQD
#   Args:
#     smiles: C(=O)=O
#     output_file: co2_coordinates.xyz
#     fmt: xyz
# ================================= Tool Message =================================
# Name: smiles_to_coordinate_file
#
# {"ok": true, "artifact": "coordinate_file", "path": "/Users/tpham2/work/projects/ChemGraph/notebooks/co2_coordinates.xyz", "smiles": "C(=O)=O", "natoms": 3}
# ================================== Ai Message ==================================
# Tool Calls:
#   run_ase (call_8ogSyfUBDkDl472hvOOwfDOm)
#  Call ID: call_8ogSyfUBDkDl472hvOOwfDOm
#   Args:
#     params: {'input_structure_file': '/Users/tpham2/work/projects/ChemGraph/notebooks/co2_coordinates.xyz', 'driver': 'vib', 'calculator': {'calculator_type': 'mace_mp'}, 'output_results_file': 'vibrational_frequencies.json'}
# /Users/tpham2/work/projects/ChemGraph/env/chemgraph_env/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# Using medium MPA-0 model as default MACE-MP model, to use previous (before 3.10) default model please specify 'medium' as model argument
# Using Materials Project MACE for MACECalculator with /Users/tpham2/.cache/mace/macempa0mediummodel
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using head default out of ['default']
# /Users/tpham2/work/projects/ChemGraph/env/chemgraph_env/lib/python3.10/site-packages/mace/calculators/mace.py:197: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   torch.load(f=model_path, map_location=device)
#       Step     Time          Energy          fmax
# BFGS:    0 11:06:02      -22.207027        5.222607
# BFGS:    1 11:06:02      -22.524121        1.564170
# BFGS:    2 11:06:02      -22.544926        0.320659
# BFGS:    3 11:06:02      -22.545908        0.014185
# BFGS:    4 11:06:02      -22.545910        0.000151
# ================================= Tool Message =================================
# Name: run_ase
#
# {"status": "success", "result": {"vibrational_frequencies": {"energies": ["0.005803356087382807i", "0.005063152340331718i", "0.005062381010971947i", "0.8475454745753854", "0.8484289493730258", "92.16121413784865", "92.16124632885807", "166.31933077063405", "286.282255806037"], "energy_unit": "meV", "frequencies": ["0.046807223898285094i", "0.04083707800392986i", "0.040830856813036435i", "6.8359153212532355", "6.843041026110733", "743.3303281642188", "743.3305878022219", "1341.4558811787222", "2309.0221319957745"], "frequency_unit": "cm-1"}}, "message": "Vibrational analysis completed; frequencies returned. Full results (structure, vibrations and metadata) saved to vibrational_frequencies.json."}
# ================================== Ai Message ==================================
#
# The vibrational frequencies of carbon dioxide (CO₂) using the MACE MP calculator have been successfully calculated. Here are the results:
#
# - **Frequencies (in cm⁻¹)**:
#   - 0.0468 (imaginary)
#   - 0.0408 (imaginary)
#   - 0.0408 (imaginary)
#   - 6.8359
#   - 6.8430
#   - 743.3303
#   - 743.3306
#   - 1341.4559
#   - 2309.0221
#
# - **Energy Unit**: meV
# - **Frequency Unit**: cm⁻¹
#
# The full results, including structure, vibrations, and metadata, have been saved to a file named `vibrational_frequencies.json`. If you need further details or specific analyses, please let me know!
# ================================ Human Message =================================
#
# {"answer":{"frequency_cm1":["0.046807223898285094i","0.04083707800392986i","0.040830856813036435i","6.8359153212532355","6.843041026110733","743.3303281642188","743.3305878022219","1341.4558811787222","2309.0221319957745"]}}

# %%
print(result_2)
# Out:
# {'messages': [{'content': 'What is the smiles string caffeine?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'dc51aea6-81c8-4f20-8585-0903192315fd'}, {'content': '', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 19, 'prompt_tokens': 4163, 'total_tokens': 4182, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-D0sPhxXLyH2rvZV9TAMvq0MMRhXll', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--4f8333a0-6e2b-459f-82e2-dba332375a5a-0', 'tool_calls': [{'name': 'molecule_name_to_smiles', 'args': {'name': 'caffeine'}, 'id': 'call_bRAsSszt2QW6aelHp1zHTDmR', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 4163, 'output_tokens': 19, 'total_tokens': 4182, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': 'CN1C=NC2=C1C(=O)N(C(=O)N2C)C', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'molecule_name_to_smiles', 'id': '2e3b3360-8819-478e-83a8-b9c58b41e795', 'tool_call_id': 'call_bRAsSszt2QW6aelHp1zHTDmR', 'artifact': None, 'status': 'success'}, {'content': 'The SMILES string for caffeine is: **CN1C=NC2=C1C(=O)N(C(=O)N2C)C**.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 36, 'prompt_tokens': 4591, 'total_tokens': 4627, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0sPkUo5fmqvfbJ2M3znspmhoDIrl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--46dac326-2cb1-4ee7-81b0-e8feb8efd7ca-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 4591, 'output_tokens': 36, 'total_tokens': 4627, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '{"answer":"CN1C=NC2=C1C(=O)N(C(=O)N2C)C"}', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '6c8155d7-e255-4131-a8b8-9c3f07f76cdc'}]}

# %%
# Calculate the enthalpy of water at 400K using MACE MP

query_3 = "What is the enthalpy of water at 400K using MACE MP?"
result_3 = await cg.run(query_3, {"thread_id": 3})
# Out:
# ================================ Human Message =================================
#
# What is the enthalpy of water at 400K using MACE MP?
# ================================== Ai Message ==================================
# Tool Calls:
#   smiles_to_coordinate_file (call_9IN4rOpt0muSKk12mSAS5N4b)
#  Call ID: call_9IN4rOpt0muSKk12mSAS5N4b
#   Args:
#     smiles: O
#     output_file: water.xyz
# ================================= Tool Message =================================
# Name: smiles_to_coordinate_file
#
# {"ok": true, "artifact": "coordinate_file", "path": "/Users/tpham2/work/projects/ChemGraph/notebooks/water.xyz", "smiles": "O", "natoms": 3}
# ================================== Ai Message ==================================
# Tool Calls:
#   run_ase (call_nljA76nXM3qe2ID1LMBntwPn)
#  Call ID: call_nljA76nXM3qe2ID1LMBntwPn
#   Args:
#     params: {'input_structure_file': '/Users/tpham2/work/projects/ChemGraph/notebooks/water.xyz', 'output_results_file': 'output.json', 'driver': 'thermo', 'temperature': 400, 'pressure': 101325, 'calculator': {'calculator_type': 'mace_mp'}}
# Using medium MPA-0 model as default MACE-MP model, to use previous (before 3.10) default model please specify 'medium' as model argument
# Using Materials Project MACE for MACECalculator with /Users/tpham2/.cache/mace/macempa0mediummodel
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using head default out of ['default']
#       Step     Time          Energy          fmax
# BFGS:    0 11:14:55      -13.766486        0.967691
# BFGS:    1 11:14:55      -13.784153        0.264106
# BFGS:    2 11:14:55      -13.785104        0.108459
# BFGS:    3 11:14:55      -13.785897        0.075446
# /Users/tpham2/work/projects/ChemGraph/env/chemgraph_env/lib/python3.10/site-packages/mace/calculators/mace.py:197: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   torch.load(f=model_path, map_location=device)
# BFGS:    4 11:14:55      -13.786069        0.024777
# BFGS:    5 11:14:55      -13.786082        0.004130
# Enthalpy components at T = 400.00 K:
# ===============================
# E_pot                -13.786 eV
# E_ZPE                  0.577 eV
# Cv_trans (0->T)        0.052 eV
# Cv_rot (0->T)          0.052 eV
# Cv_vib (0->T)          0.001 eV
# (C_v -> C_p)           0.034 eV
# -------------------------------
# H                    -13.071 eV
# ===============================
# Entropy components at T = 400.00 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0015652 eV/K        0.626 eV
# S_rot              0.0004947 eV/K        0.198 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000015 eV/K        0.001 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.000 eV
# -------------------------------------------------
# S                  0.0020603 eV/K        0.824 eV
# =================================================
# Enthalpy components at T = 400.00 K:
# ===============================
# E_pot                -13.786 eV
# E_ZPE                  0.577 eV
# Cv_trans (0->T)        0.052 eV
# Cv_rot (0->T)          0.052 eV
# Cv_vib (0->T)          0.001 eV
# (C_v -> C_p)           0.034 eV
# -------------------------------
# H                    -13.071 eV
# ===============================
#
# Entropy components at T = 400.00 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0015652 eV/K        0.626 eV
# S_rot              0.0004947 eV/K        0.198 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000015 eV/K        0.001 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.000 eV
# -------------------------------------------------
# S                  0.0020603 eV/K        0.824 eV
# =================================================
#
# Free energy components at T = 400.00 K and P = 101325.0 Pa:
# =======================
#     H        -13.071 eV
#  -T*S         -0.824 eV
# -----------------------
#     G        -13.895 eV
# =======================
# ================================= Tool Message =================================
# Name: run_ase
#
# {"status": "success", "result": {"thermochemistry": {"enthalpy": -13.071059736294183, "entropy": 0.0020602946707283815, "gibbs_free_energy": -13.895177604585536, "unit": "eV"}}, "message": "Thermochemistry computed and returned. Full results (structure, vibrations, thermochemistry and metadata) saved to output.json"}
# ================================== Ai Message ==================================
#
# The enthalpy of water at 400 K, calculated using the MACE MP method, is approximately **-13.07 eV**.
#
# Additional thermochemical properties obtained from the calculation include:
# - Entropy: **0.00206 eV**
# - Gibbs Free Energy: **-13.90 eV**
#
# These results have been saved to the file `output.json`.
# ================================ Human Message =================================
#
# {"answer":{"value":-13.071059736294183,"property":"enthalpy","unit":"eV"}}
