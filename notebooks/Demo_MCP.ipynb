# %%
import nest_asyncio, asyncio, sys, json
from langchain_mcp_adapters.client import MultiServerMCPClient
from chemgraph.agent.llm_agent_mcp import ChemGraph
from chemgraph.tools.ase_tools import run_ase

path_to_mcp = "/Users/tpham2/work/projects/ChemGraph/mcp_tools.py"
prompt_single = "What is the enthalpy of CO2 using TBLite GFN2-xTB at 400K?"
prompt_multi = "You are given a chemical reaction: 1 (Nitrogen gas) + 3 (Hydrogen gas) -> 2 (Ammonia). Calculate the enthalpy change (detal H) for this reaction using GFN2-xTB at 400K."

client = MultiServerMCPClient({
    "Chemistry Tools MCP": {
        "command": "python",
        "args": [path_to_mcp],
    	"transport": "stdio",
    },
}
)
async def bootstrap():
	tools = await client.get_tools()
	cg = ChemGraph(
		model_name="gpt-4o-mini",
		workflow_type="single_agent",
		#workflow_type="multi_agent",
	    structured_output=True,
	    return_option="state",
	    tools=tools,
	)
	result = await cg.run(prompt_single)
	print(result)

try:
    get_ipython  # type: ignore  # noqa: F401
    await bootstrap()
except NameError:
    asyncio.run(bootstrap())
# Out:
# 2025-09-29 13:28:11,233 - chemgraph.tools.openai_loader - INFO - Loading OpenAI model: gpt-4o-mini
# INFO:chemgraph.tools.openai_loader:Loading OpenAI model: gpt-4o-mini
# 2025-09-29 13:28:11,234 - chemgraph.tools.openai_loader - INFO - Requested model: gpt-4o-mini
# INFO:chemgraph.tools.openai_loader:Requested model: gpt-4o-mini
# 2025-09-29 13:28:11,234 - chemgraph.tools.openai_loader - INFO - OpenAI model loaded successfully
# INFO:chemgraph.tools.openai_loader:OpenAI model loaded successfully
# 2025-09-29 13:28:11,235 - chemgraph.graphs.single_agent - INFO - Constructing single agent graph
# INFO:chemgraph.graphs.single_agent:Constructing single agent graph
# 2025-09-29 13:28:11,237 - chemgraph.graphs.single_agent - INFO - Graph construction completed
# INFO:chemgraph.graphs.single_agent:Graph construction completed
# ================================ Human Message =================================
#
# What is the enthalpy of CO2 using TBLite GFN2-xTB at 400K?
# ================================== Ai Message ==================================
# Tool Calls:
#   smiles_to_coordinate_file (call_OolpW4Q5cRSUL72vvMs57jTy)
#  Call ID: call_OolpW4Q5cRSUL72vvMs57jTy
#   Args:
#     smiles: O=C=O
#     output_file: CO2.xyz
# ================================= Tool Message =================================
# Name: smiles_to_coordinate_file
#
# {
#   "ok": true,
#   "artifact": "coordinate_file",
#   "path": "/Users/tpham2/work/projects/ChemGraph/notebooks/CO2.xyz",
#   "smiles": "O=C=O",
#   "natoms": 3
# }
# ================================== Ai Message ==================================
# Tool Calls:
#   run_ase (call_bxduOpaUTLfleaWLKET92Jsk)
#  Call ID: call_bxduOpaUTLfleaWLKET92Jsk
#   Args:
#     params: {'input_structure_file': 'CO2.xyz', 'output_results_file': 'output.json', 'driver': 'thermo', 'temperature': 400, 'pressure': 101325, 'calculator': {'calculator_type': 'TBLite', 'method': 'GFN2-xTB'}}
# ================================= Tool Message =================================
# Name: run_ase
#
# {
#   "status": "success",
#   "result": {
#     "thermochemistry": {
#       "enthalpy": -280.04249057964546,
#       "entropy": 0.0023421562390273914,
#       "gibbs_free_energy": -280.9793530752564,
#       "unit": "eV"
#     }
#   },
#   "message": "Thermochemistry computed and returned. Full results (structure, vibrations, thermochemistry and metadata) saved to /Users/tpham2/work/projects/ChemGraph/notebooks/output.json"
# }
# ================================== Ai Message ==================================
#
# The enthalpy of CO2 at 400 K, calculated using the TBLite GFN2-xTB method, is approximately **-280.04 eV**.
#
# Additional thermochemical properties obtained include:
# - **Entropy**: 0.00234 eV
# - **Gibbs Free Energy**: -280.98 eV
#
# These results are saved in the output file located at `/Users/tpham2/work/projects/ChemGraph/notebooks/output.json`.
# ================================ Human Message =================================
#
# {"answer":{"value":-280.04249057964546,"property":"enthalpy","unit":"eV"}}
# {'messages': [{'content': 'What is the enthalpy of CO2 using TBLite GFN2-xTB at 400K?', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'b59b2337-ccc1-491b-917f-bcc032216db7', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_OolpW4Q5cRSUL72vvMs57jTy', 'function': {'arguments': '{"smiles":"O=C=O","output_file":"CO2.xyz"}', 'name': 'smiles_to_coordinate_file'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 28, 'prompt_tokens': 3478, 'total_tokens': 3506, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3328}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CLCtXIkWDGk0tWi4jb50ftyhJtmly', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--04420b60-1a04-44aa-bd24-bc3c08dee515-0', 'example': False, 'tool_calls': [{'name': 'smiles_to_coordinate_file', 'args': {'smiles': 'O=C=O', 'output_file': 'CO2.xyz'}, 'id': 'call_OolpW4Q5cRSUL72vvMs57jTy', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 3478, 'output_tokens': 28, 'total_tokens': 3506, 'input_token_details': {'audio': 0, 'cache_read': 3328}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '{\n  "ok": true,\n  "artifact": "coordinate_file",\n  "path": "/Users/tpham2/work/projects/ChemGraph/notebooks/CO2.xyz",\n  "smiles": "O=C=O",\n  "natoms": 3\n}', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'smiles_to_coordinate_file', 'id': '0b3591f4-03ba-480c-82c4-703ee058a5b6', 'tool_call_id': 'call_OolpW4Q5cRSUL72vvMs57jTy', 'artifact': None, 'status': 'success'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_bxduOpaUTLfleaWLKET92Jsk', 'function': {'arguments': '{"params":{"input_structure_file":"CO2.xyz","output_results_file":"output.json","driver":"thermo","temperature":400,"pressure":101325,"calculator":{"calculator_type":"TBLite","method":"GFN2-xTB"}}}', 'name': 'run_ase'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 60, 'prompt_tokens': 4006, 'total_tokens': 4066, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3456}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CLCtbgYpXalbrhq9CJ6CAMW4GE6Y1', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--3eff0c91-1afa-4b9f-aed8-3fe6460bd126-0', 'example': False, 'tool_calls': [{'name': 'run_ase', 'args': {'params': {'input_structure_file': 'CO2.xyz', 'output_results_file': 'output.json', 'driver': 'thermo', 'temperature': 400, 'pressure': 101325, 'calculator': {'calculator_type': 'TBLite', 'method': 'GFN2-xTB'}}}, 'id': 'call_bxduOpaUTLfleaWLKET92Jsk', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 4006, 'output_tokens': 60, 'total_tokens': 4066, 'input_token_details': {'audio': 0, 'cache_read': 3456}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '{\n  "status": "success",\n  "result": {\n    "thermochemistry": {\n      "enthalpy": -280.04249057964546,\n      "entropy": 0.0023421562390273914,\n      "gibbs_free_energy": -280.9793530752564,\n      "unit": "eV"\n    }\n  },\n  "message": "Thermochemistry computed and returned. Full results (structure, vibrations, thermochemistry and metadata) saved to /Users/tpham2/work/projects/ChemGraph/notebooks/output.json"\n}', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'run_ase', 'id': '5505e41f-2ff8-432f-b541- ...
